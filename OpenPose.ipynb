# %% [markdown]
# ### Mobilize Center & Restore Center @ Stanford Tutorial
# # Pose Estimation for Biomechanics
#
# Quantitative motion analysis is important for the diagnostics of movement disorders and for research. State-of-the-art measurements involve optical motion capture using reflective markers and expensive cameras to capture trajectories of these markers. Though the technique provides high frequency data for assessment, the cost, skills, and time involved limit wide adoption.
#
# Recent advancements in deep learning allow us to very robustly detect body landmarks (such as toes, hips, shoulders, etc.) in images from commodity cameras, such as found in smartphones. We can apply these techniques to videos to derive trajectories of landmarks in time. Recent studies show that these trajectories can be used for some clinical applications, potentially reducing the cost of movement analyses by orders of magnitude and facilitating more frequent assessments.
#
# ##Tutorial Overview
# **In this notebook we illustrate how to use one deep learning algorithm to analyze human motion. Specifically, we will extract knee flexion curves and gait cycles from a video of a subject walking.** The notebook is for illustrative purposes only, and multiple improvements should be incorporated to obtain accurate knee flexion angles. However, the notebook does provide a pipeline that you can adapt to get started with video-based pose estimation projects.
#
# The notebook is a part of the [Mobilize Center](https://mobilize.stanford.edu) webinar series, and is jointly offered with the [Restore Center](https://restore.stanford.edu). The Mobilize Center is an NIH-funded Biomedical Technology Resource Center which provides tools and training to help researchers produce insights from wearables, video, medical images, and other data sources. The Restore Center is an NIH Medical Rehabilitation Research Resource Network Center which is creating a worldwide collaboration to advance the use of real-world data in rehabilitation outcomes for those with movement impairments.
#
# ##Background and Citation
# Most of the [code](https://github.com/stanfordnmbl/mobile-gaitlab) in this notebook comes from our study on gait analysis in the cerebral palsy population. To cite our work, please use:
#
# *Łukasz Kidziński, Bryan Yang, Jennifer L. Hicks, Apoorva Rajagopal, Scott L. Delp, and Michael H. Schwartz. "Deep neural networks enable quantitative movement analysis using single-camera videos." Nature communications 11, no. 1 (2020): 1-10.*
#
# Learn more about this work:
# * [Read our publication](https://www.nature.com/articles/s41467-020-17807-z)
# * Watch the video abstract of this study below

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('pb4WvAhsRe4')

# %% [markdown]
# ## Learning Goals
#
# In this tutorial notebook, you will learn how to:
#
# * Set up a Google Colab notebook to run OpenPose
#   - Download OpenPose
#   - Download a sample video
# * Run OpenPose on a sample video and work with its output
#   - Interpret output JSON files
#   - Convert files to a numpy time series
# * Preprocess data
#   - Fix missing data with interpolation
#   - Fix noise with a Gaussian filter
#   - Fix bias with normalization
# * Perform the analysis
#   - Derive joint angles
#   - Find gait cycles
#   - Report results
#
#
#
# **Prefer to follow along via video?** [Access a recording](https://www.youtube.com/watch?v=Js0uRTLfm6s&t=4s) of Łukasz Kidziński guiding users through this tutorial

# %% [markdown]
# # Setup

# %% [markdown]
# ## Introduction to Google Colab
#
# Google Colab is a cloud-based environment for running Python code interactively (via Jupyter notebooks, for those who are familiar with those). If you are new to Colab, you can learn about the key features in [this tutorial](https://colab.research.google.com/notebooks/basic_features_overview.ipynb). For the purposes of our tutorial, you only need to understand how to interact with the "code cells." In the [webinar recording](https://www.youtube.com/watch?v=Js0uRTLfm6s&t=4s), we also provide a quick overview of how to work with this Colab notebook.

# %% [markdown]
# ## Installation
#
# Run the code below to download and compile OpenPose within your Google Colab environment (based on [tugstugi/dl-colab-notebooks](https://github.com/tugstugi/dl-colab-notebooks)). **This takes around 1 minute.** It is done when you see `[100%] Built target openpose_net`.

# %%
import os
if not os.path.exists("openpose"):
  # !apt-get -qq install -y libatlas-base-dev libprotobuf-dev libleveldb-dev libsnappy-dev libhdf5-serial-dev protobuf-compiler libgflags-dev libgoogle-glog-dev liblmdb-dev opencl-headers ocl-icd-opencl-dev libviennacl-dev
  # !pip install -q youtube-dl
  # !wget https://motionlab-storage.s3-us-west-2.amazonaws.com/openpose.tar.gz
  # !tar -zxvf openpose.tar.gz
  # !wget -q https://cmake.org/files/v3.13/cmake-3.13.0-Linux-x86_64.tar.gz
  # !tar xfz cmake-3.13.0-Linux-x86_64.tar.gz --strip-components=1 -C /usr/local
  # !cd openpose/build && cmake .. && make -j`nproc`
# Out:
# Selecting previously unselected package libgflags2.2.
# (Reading database ... 160690 files and directories currently installed.)
# Preparing to unpack .../00-libgflags2.2_2.2.1-1_amd64.deb ...
# Unpacking libgflags2.2 (2.2.1-1) ...
# Selecting previously unselected package libgflags-dev.
# Preparing to unpack .../01-libgflags-dev_2.2.1-1_amd64.deb ...
# Unpacking libgflags-dev (2.2.1-1) ...
# Selecting previously unselected package libgoogle-glog0v5.
# Preparing to unpack .../02-libgoogle-glog0v5_0.3.5-1_amd64.deb ...
# Unpacking libgoogle-glog0v5 (0.3.5-1) ...
# Selecting previously unselected package libgoogle-glog-dev.
# Preparing to unpack .../03-libgoogle-glog-dev_0.3.5-1_amd64.deb ...
# Unpacking libgoogle-glog-dev (0.3.5-1) ...
# Selecting previously unselected package libhdf5-serial-dev.
# Preparing to unpack .../04-libhdf5-serial-dev_1.10.0-patch1+docs-4_all.deb ...
# Unpacking libhdf5-serial-dev (1.10.0-patch1+docs-4) ...
# Selecting previously unselected package libleveldb1v5:amd64.
# Preparing to unpack .../05-libleveldb1v5_1.20-2_amd64.deb ...
# Unpacking libleveldb1v5:amd64 (1.20-2) ...
# Selecting previously unselected package libleveldb-dev:amd64.
# Preparing to unpack .../06-libleveldb-dev_1.20-2_amd64.deb ...
# Unpacking libleveldb-dev:amd64 (1.20-2) ...
# Selecting previously unselected package liblmdb0:amd64.
# Preparing to unpack .../07-liblmdb0_0.9.21-1ubuntu0.1_amd64.deb ...
# Unpacking liblmdb0:amd64 (0.9.21-1ubuntu0.1) ...
# Selecting previously unselected package liblmdb-dev:amd64.
# Preparing to unpack .../08-liblmdb-dev_0.9.21-1ubuntu0.1_amd64.deb ...
# Unpacking liblmdb-dev:amd64 (0.9.21-1ubuntu0.1) ...
# Selecting previously unselected package libprotobuf-lite10:amd64.
# Preparing to unpack .../09-libprotobuf-lite10_3.0.0-9.1ubuntu1_amd64.deb ...
# Unpacking libprotobuf-lite10:amd64 (3.0.0-9.1ubuntu1) ...
# Selecting previously unselected package lmdb-doc.
# Preparing to unpack .../10-lmdb-doc_0.9.21-1ubuntu0.1_all.deb ...
# Unpacking lmdb-doc (0.9.21-1ubuntu0.1) ...
# Selecting previously unselected package libprotobuf-dev:amd64.
# Preparing to unpack .../11-libprotobuf-dev_3.0.0-9.1ubuntu1_amd64.deb ...
# Unpacking libprotobuf-dev:amd64 (3.0.0-9.1ubuntu1) ...
# Selecting previously unselected package libsnappy-dev:amd64.
# Preparing to unpack .../12-libsnappy-dev_1.1.7-1_amd64.deb ...
# Unpacking libsnappy-dev:amd64 (1.1.7-1) ...
# Selecting previously unselected package libviennacl-dev.
# Preparing to unpack .../13-libviennacl-dev_1.7.1+dfsg1-2ubuntu1_all.deb ...
# Unpacking libviennacl-dev (1.7.1+dfsg1-2ubuntu1) ...
# Selecting previously unselected package opencl-clhpp-headers.
# Preparing to unpack .../14-opencl-clhpp-headers_2.0.10+git12-g5dd8bb9-1_all.deb ...
# Unpacking opencl-clhpp-headers (2.0.10+git12-g5dd8bb9-1) ...
# Selecting previously unselected package opencl-headers.
# Preparing to unpack .../15-opencl-headers_2.2~2018.02.21-gb5c3680-1_all.deb ...
# Unpacking opencl-headers (2.2~2018.02.21-gb5c3680-1) ...
# Setting up libviennacl-dev (1.7.1+dfsg1-2ubuntu1) ...
# Setting up libgflags2.2 (2.2.1-1) ...
# Setting up libgflags-dev (2.2.1-1) ...
# Setting up liblmdb0:amd64 (0.9.21-1ubuntu0.1) ...
# Setting up opencl-clhpp-headers (2.0.10+git12-g5dd8bb9-1) ...
# Setting up libleveldb1v5:amd64 (1.20-2) ...
# Setting up libhdf5-serial-dev (1.10.0-patch1+docs-4) ...
# Setting up libsnappy-dev:amd64 (1.1.7-1) ...
# Setting up libgoogle-glog0v5 (0.3.5-1) ...
# Setting up liblmdb-dev:amd64 (0.9.21-1ubuntu0.1) ...
# Setting up lmdb-doc (0.9.21-1ubuntu0.1) ...
# Setting up libprotobuf-lite10:amd64 (3.0.0-9.1ubuntu1) ...
# Setting up opencl-headers (2.2~2018.02.21-gb5c3680-1) ...
# Setting up libprotobuf-dev:amd64 (3.0.0-9.1ubuntu1) ...
# Setting up libleveldb-dev:amd64 (1.20-2) ...
# Setting up libgoogle-glog-dev (0.3.5-1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
#      |████████████████████████████████| 1.9MB 20.8MB/s
# --2021-04-27 14:28:18--  https://motionlab-storage.s3-us-west-2.amazonaws.com/openpose.tar.gz
# Resolving motionlab-storage.s3-us-west-2.amazonaws.com (motionlab-storage.s3-us-west-2.amazonaws.com)... 52.218.242.25
# Connecting to motionlab-storage.s3-us-west-2.amazonaws.com (motionlab-storage.s3-us-west-2.amazonaws.com)|52.218.242.25|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 582748906 (556M) [application/x-gzip]
# Saving to: ‘openpose.tar.gz’
#
# openpose.tar.gz     100%[===================>] 555.75M  37.2MB/s    in 16s
#
# 2021-04-27 14:28:35 (34.0 MB/s) - ‘openpose.tar.gz’ saved [582748906/582748906]
#
# openpose/
# openpose/build/
# openpose/build/detect_cuda_archs.cu
# openpose/build/caffe/
# openpose/build/caffe/lib/
# openpose/build/caffe/lib/libcaffeproto.a
# openpose/build/caffe/lib/libcaffe.so.1.0.0
# openpose/build/caffe/lib/libcaffe.so
# openpose/build/caffe/bin/
# openpose/build/caffe/bin/convert_cifar_data
# openpose/build/caffe/bin/extract_features
# openpose/build/caffe/bin/caffe
# openpose/build/caffe/bin/upgrade_net_proto_text
# openpose/build/caffe/bin/convert_mnist_data
# openpose/build/caffe/bin/compute_image_mean
# openpose/build/caffe/bin/upgrade_solver_proto_text
# openpose/build/caffe/bin/upgrade_net_proto_binary
# openpose/build/caffe/bin/convert_imageset
# openpose/build/caffe/bin/classification
# openpose/build/caffe/bin/convert_mnist_siamese_data
# openpose/build/caffe/share/
# openpose/build/caffe/share/Caffe/
# openpose/build/caffe/share/Caffe/CaffeConfig.cmake
# openpose/build/caffe/share/Caffe/CaffeTargets.cmake
# openpose/build/caffe/share/Caffe/CaffeTargets-release.cmake
# openpose/build/caffe/include/
# openpose/build/caffe/include/caffe/
# openpose/build/caffe/include/caffe/parallel.hpp
# openpose/build/caffe/include/caffe/layers/
# openpose/build/caffe/include/caffe/layers/inner_product_layer.hpp
# openpose/build/caffe/include/caffe/layers/cudnn_relu_layer.hpp
# openpose/build/caffe/include/caffe/layers/softmax_layer.hpp
# openpose/build/caffe/include/caffe/layers/cudnn_tanh_layer.hpp
# openpose/build/caffe/include/caffe/layers/threshold_layer.hpp
# openpose/build/caffe/include/caffe/layers/multinomial_logistic_loss_layer.hpp
# openpose/build/caffe/include/caffe/layers/prelu_layer.hpp
# openpose/build/caffe/include/caffe/layers/sigmoid_cross_entropy_loss_layer.hpp
# openpose/build/caffe/include/caffe/layers/data_layer.hpp
# openpose/build/caffe/include/caffe/layers/loss_layer.hpp
# openpose/build/caffe/include/caffe/layers/im2col_layer.hpp
# openpose/build/caffe/include/caffe/layers/base_conv_layer.hpp
# openpose/build/caffe/include/caffe/layers/scale_layer.hpp
# openpose/build/caffe/include/caffe/layers/hdf5_data_layer.hpp
# openpose/build/caffe/include/caffe/layers/input_layer.hpp
# openpose/build/caffe/include/caffe/layers/hdf5_output_layer.hpp
# openpose/build/caffe/include/caffe/layers/cudnn_lcn_layer.hpp
# openpose/build/caffe/include/caffe/layers/crop_layer.hpp
# openpose/build/caffe/include/caffe/layers/batch_norm_layer.hpp
# openpose/build/caffe/include/caffe/layers/dropout_layer.hpp
# openpose/build/caffe/include/caffe/layers/lstm_layer.hpp
# openpose/build/caffe/include/caffe/layers/memory_data_layer.hpp
# openpose/build/caffe/include/caffe/layers/flatten_layer.hpp
# openpose/build/caffe/include/caffe/layers/bias_layer.hpp
# openpose/build/caffe/include/caffe/layers/base_data_layer.hpp
# openpose/build/caffe/include/caffe/layers/hinge_loss_layer.hpp
# openpose/build/caffe/include/caffe/layers/embed_layer.hpp
# openpose/build/caffe/include/caffe/layers/exp_layer.hpp
# openpose/build/caffe/include/caffe/layers/recurrent_layer.hpp
# openpose/build/caffe/include/caffe/layers/reduction_layer.hpp
# openpose/build/caffe/include/caffe/layers/parameter_layer.hpp
# openpose/build/caffe/include/caffe/layers/reshape_layer.hpp
# openpose/build/caffe/include/caffe/layers/cudnn_conv_layer.hpp
# openpose/build/caffe/include/caffe/layers/sigmoid_layer.hpp
# openpose/build/caffe/include/caffe/layers/batch_reindex_layer.hpp
# openpose/build/caffe/include/caffe/layers/power_layer.hpp
# openpose/build/caffe/include/caffe/layers/conv_layer.hpp
# openpose/build/caffe/include/caffe/layers/spp_layer.hpp
# openpose/build/caffe/include/caffe/layers/euclidean_loss_layer.hpp
# openpose/build/caffe/include/caffe/layers/deconv_layer.hpp
# openpose/build/caffe/include/caffe/layers/pooling_layer.hpp
# openpose/build/caffe/include/caffe/layers/lrn_layer.hpp
# openpose/build/caffe/include/caffe/layers/eltwise_layer.hpp
# openpose/build/caffe/include/caffe/layers/bnll_layer.hpp
# openpose/build/caffe/include/caffe/layers/elu_layer.hpp
# openpose/build/caffe/include/caffe/layers/infogain_loss_layer.hpp
# openpose/build/caffe/include/caffe/layers/neuron_layer.hpp
# openpose/build/caffe/include/caffe/layers/swish_layer.hpp
# openpose/build/caffe/include/caffe/layers/rnn_layer.hpp
# openpose/build/caffe/include/caffe/layers/softmax_loss_layer.hpp
# openpose/build/caffe/include/caffe/layers/accuracy_layer.hpp
# openpose/build/caffe/include/caffe/layers/relu_layer.hpp
# openpose/build/caffe/include/caffe/layers/cudnn_lrn_layer.hpp
# openpose/build/caffe/include/caffe/layers/tanh_layer.hpp
# openpose/build/caffe/include/caffe/layers/dummy_data_layer.hpp
# openpose/build/caffe/include/caffe/layers/cudnn_deconv_layer.hpp
# openpose/build/caffe/include/caffe/layers/contrastive_loss_layer.hpp
# openpose/build/caffe/include/caffe/layers/absval_layer.hpp
# openpose/build/caffe/include/caffe/layers/cudnn_sigmoid_layer.hpp
# openpose/build/caffe/include/caffe/layers/argmax_layer.hpp
# openpose/build/caffe/include/caffe/layers/cudnn_softmax_layer.hpp
# openpose/build/caffe/include/caffe/layers/log_layer.hpp
# openpose/build/caffe/include/caffe/layers/clip_layer.hpp
# openpose/build/caffe/include/caffe/layers/mvn_layer.hpp
# openpose/build/caffe/include/caffe/layers/split_layer.hpp
# openpose/build/caffe/include/caffe/layers/silence_layer.hpp
# openpose/build/caffe/include/caffe/layers/python_layer.hpp
# openpose/build/caffe/include/caffe/layers/window_data_layer.hpp
# openpose/build/caffe/include/caffe/layers/filter_layer.hpp
# openpose/build/caffe/include/caffe/layers/cudnn_pooling_layer.hpp
# openpose/build/caffe/include/caffe/layers/tile_layer.hpp
# openpose/build/caffe/include/caffe/layers/image_data_layer.hpp
# openpose/build/caffe/include/caffe/layers/slice_layer.hpp
# openpose/build/caffe/include/caffe/layers/concat_layer.hpp
# openpose/build/caffe/include/caffe/sgd_solvers.hpp
# openpose/build/caffe/include/caffe/filler.hpp
# openpose/build/caffe/include/caffe/blob.hpp
# openpose/build/caffe/include/caffe/layer_factory.hpp
# openpose/build/caffe/include/caffe/common.hpp
# openpose/build/caffe/include/caffe/util/
# openpose/build/caffe/include/caffe/util/device_alternate.hpp
# openpose/build/caffe/include/caffe/util/math_functions.hpp
# openpose/build/caffe/include/caffe/util/signal_handler.h
# openpose/build/caffe/include/caffe/util/mkl_alternate.hpp
# openpose/build/caffe/include/caffe/util/io.hpp
# openpose/build/caffe/include/caffe/util/format.hpp
# openpose/build/caffe/include/caffe/util/db_leveldb.hpp
# openpose/build/caffe/include/caffe/util/cudnn.hpp
# openpose/build/caffe/include/caffe/util/benchmark.hpp
# openpose/build/caffe/include/caffe/util/db_lmdb.hpp
# openpose/build/caffe/include/caffe/util/im2col.hpp
# openpose/build/caffe/include/caffe/util/rng.hpp
# openpose/build/caffe/include/caffe/util/insert_splits.hpp
# openpose/build/caffe/include/caffe/util/upgrade_proto.hpp
# openpose/build/caffe/include/caffe/util/hdf5.hpp
# openpose/build/caffe/include/caffe/util/blocking_queue.hpp
# openpose/build/caffe/include/caffe/util/gpu_util.cuh
# openpose/build/caffe/include/caffe/util/db.hpp
# openpose/build/caffe/include/caffe/util/nccl.hpp
# openpose/build/caffe/include/caffe/internal_thread.hpp
# openpose/build/caffe/include/caffe/caffe.hpp
# openpose/build/caffe/include/caffe/net.hpp
# openpose/build/caffe/include/caffe/layer.hpp
# openpose/build/caffe/include/caffe/test/
# openpose/build/caffe/include/caffe/test/test_gradient_check_util.hpp
# openpose/build/caffe/include/caffe/test/test_caffe_main.hpp
# openpose/build/caffe/include/caffe/syncedmem.hpp
# openpose/build/caffe/include/caffe/data_transformer.hpp
# openpose/build/caffe/include/caffe/proto/
# openpose/build/caffe/include/caffe/proto/caffe.pb.h
# openpose/build/caffe/include/caffe/solver_factory.hpp
# openpose/build/caffe/include/caffe/solver.hpp
# openpose/build/caffe/src/
# openpose/build/caffe/src/openpose_lib-build/
# openpose/build/caffe/src/openpose_lib-build/lib/
# openpose/build/caffe/src/openpose_lib-build/lib/libcaffeproto.a
# openpose/build/caffe/src/openpose_lib-build/lib/libcaffe.so.1.0.0
# openpose/build/caffe/src/openpose_lib-build/lib/libcaffe.so
# openpose/build/caffe/src/openpose_lib-build/CaffeConfig.cmake
# openpose/build/caffe/src/openpose_lib-build/install_manifest.txt
# openpose/build/caffe/src/openpose_lib-build/tools/
# openpose/build/caffe/src/openpose_lib-build/tools/extract_features
# openpose/build/caffe/src/openpose_lib-build/tools/caffe
# openpose/build/caffe/src/openpose_lib-build/tools/upgrade_net_proto_text
# openpose/build/caffe/src/openpose_lib-build/tools/compute_image_mean
# openpose/build/caffe/src/openpose_lib-build/tools/cmake_install.cmake
# openpose/build/caffe/src/openpose_lib-build/tools/Makefile
# openpose/build/caffe/src/openpose_lib-build/tools/upgrade_solver_proto_text
# openpose/build/caffe/src/openpose_lib-build/tools/upgrade_net_proto_binary
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/convert_imageset.dir/
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/convert_imageset.dir/convert_imageset.cpp.o
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/convert_imageset.dir/build.make
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/convert_imageset.dir/flags.make
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/convert_imageset.dir/depend.internal
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/convert_imageset.dir/CXX.includecache
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/convert_imageset.dir/DependInfo.cmake
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/convert_imageset.dir/cmake_clean.cmake
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/convert_imageset.dir/depend.make
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/convert_imageset.dir/link.txt
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/convert_imageset.dir/progress.make
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/progress.marks
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/upgrade_solver_proto_text.dir/
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/upgrade_solver_proto_text.dir/upgrade_solver_proto_text.cpp.o
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/upgrade_solver_proto_text.dir/build.make
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/upgrade_solver_proto_text.dir/flags.make
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/upgrade_solver_proto_text.dir/depend.internal
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/upgrade_solver_proto_text.dir/CXX.includecache
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/upgrade_solver_proto_text.dir/DependInfo.cmake
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/upgrade_solver_proto_text.dir/cmake_clean.cmake
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/upgrade_solver_proto_text.dir/depend.make
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/upgrade_solver_proto_text.dir/link.txt
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/upgrade_solver_proto_text.dir/progress.make
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/upgrade_net_proto_text.dir/
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/upgrade_net_proto_text.dir/build.make
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/upgrade_net_proto_text.dir/flags.make
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/upgrade_net_proto_text.dir/upgrade_net_proto_text.cpp.o
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/upgrade_net_proto_text.dir/depend.internal
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/upgrade_net_proto_text.dir/CXX.includecache
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/upgrade_net_proto_text.dir/DependInfo.cmake
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/upgrade_net_proto_text.dir/cmake_clean.cmake
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/upgrade_net_proto_text.dir/depend.make
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/upgrade_net_proto_text.dir/link.txt
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/upgrade_net_proto_text.dir/progress.make
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/CMakeDirectoryInformation.cmake
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/caffe.bin.dir/
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/caffe.bin.dir/caffe.cpp.o
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/caffe.bin.dir/build.make
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/caffe.bin.dir/flags.make
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/caffe.bin.dir/depend.internal
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/caffe.bin.dir/CXX.includecache
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/caffe.bin.dir/DependInfo.cmake
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/caffe.bin.dir/cmake_clean.cmake
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/caffe.bin.dir/depend.make
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/caffe.bin.dir/link.txt
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/caffe.bin.dir/progress.make
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/upgrade_net_proto_binary.dir/
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/upgrade_net_proto_binary.dir/build.make
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/upgrade_net_proto_binary.dir/upgrade_net_proto_binary.cpp.o
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/upgrade_net_proto_binary.dir/flags.make
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/upgrade_net_proto_binary.dir/depend.internal
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/upgrade_net_proto_binary.dir/CXX.includecache
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/upgrade_net_proto_binary.dir/DependInfo.cmake
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/upgrade_net_proto_binary.dir/cmake_clean.cmake
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/upgrade_net_proto_binary.dir/depend.make
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/upgrade_net_proto_binary.dir/link.txt
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/upgrade_net_proto_binary.dir/progress.make
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/extract_features.dir/
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/extract_features.dir/build.make
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/extract_features.dir/flags.make
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/extract_features.dir/extract_features.cpp.o
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/extract_features.dir/depend.internal
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/extract_features.dir/CXX.includecache
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/extract_features.dir/DependInfo.cmake
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/extract_features.dir/cmake_clean.cmake
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/extract_features.dir/depend.make
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/extract_features.dir/link.txt
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/extract_features.dir/progress.make
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/compute_image_mean.dir/
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/compute_image_mean.dir/compute_image_mean.cpp.o
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/compute_image_mean.dir/build.make
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/compute_image_mean.dir/flags.make
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/compute_image_mean.dir/depend.internal
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/compute_image_mean.dir/CXX.includecache
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/compute_image_mean.dir/DependInfo.cmake
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/compute_image_mean.dir/cmake_clean.cmake
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/compute_image_mean.dir/depend.make
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/compute_image_mean.dir/link.txt
# openpose/build/caffe/src/openpose_lib-build/tools/CMakeFiles/compute_image_mean.dir/progress.make
# openpose/build/caffe/src/openpose_lib-build/tools/convert_imageset
# openpose/build/caffe/src/openpose_lib-build/detect_cuda_archs.cu
# openpose/build/caffe/src/openpose_lib-build/CMakeCache.txt
# openpose/build/caffe/src/openpose_lib-build/__init__.py
# openpose/build/caffe/src/openpose_lib-build/include/
# openpose/build/caffe/src/openpose_lib-build/include/caffe/
# openpose/build/caffe/src/openpose_lib-build/include/caffe/proto/
# openpose/build/caffe/src/openpose_lib-build/include/caffe/proto/caffe.pb.h
# openpose/build/caffe/src/openpose_lib-build/include/caffe/proto/caffe.pb.cc
# openpose/build/caffe/src/openpose_lib-build/include/caffe/proto/caffe_pb2.py
# openpose/build/caffe/src/openpose_lib-build/examples/
# openpose/build/caffe/src/openpose_lib-build/examples/siamese/
# openpose/build/caffe/src/openpose_lib-build/examples/siamese/convert_mnist_siamese_data.bin
# openpose/build/caffe/src/openpose_lib-build/examples/siamese/convert_mnist_siamese_data
# openpose/build/caffe/src/openpose_lib-build/examples/cmake_install.cmake
# openpose/build/caffe/src/openpose_lib-build/examples/Makefile
# openpose/build/caffe/src/openpose_lib-build/examples/cifar10/
# openpose/build/caffe/src/openpose_lib-build/examples/cifar10/convert_cifar_data.bin
# openpose/build/caffe/src/openpose_lib-build/examples/cifar10/convert_cifar_data
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/convert_mnist_data.dir/
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/convert_mnist_data.dir/build.make
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/convert_mnist_data.dir/flags.make
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/convert_mnist_data.dir/depend.internal
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/convert_mnist_data.dir/CXX.includecache
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/convert_mnist_data.dir/DependInfo.cmake
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/convert_mnist_data.dir/cmake_clean.cmake
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/convert_mnist_data.dir/mnist/
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/convert_mnist_data.dir/mnist/convert_mnist_data.cpp.o
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/convert_mnist_data.dir/depend.make
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/convert_mnist_data.dir/link.txt
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/convert_mnist_data.dir/progress.make
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/convert_cifar_data.dir/
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/convert_cifar_data.dir/build.make
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/convert_cifar_data.dir/flags.make
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/convert_cifar_data.dir/depend.internal
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/convert_cifar_data.dir/CXX.includecache
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/convert_cifar_data.dir/cifar10/
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/convert_cifar_data.dir/cifar10/convert_cifar_data.cpp.o
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/convert_cifar_data.dir/DependInfo.cmake
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/convert_cifar_data.dir/cmake_clean.cmake
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/convert_cifar_data.dir/depend.make
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/convert_cifar_data.dir/link.txt
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/convert_cifar_data.dir/progress.make
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/progress.marks
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/CMakeDirectoryInformation.cmake
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/classification.dir/
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/classification.dir/build.make
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/classification.dir/flags.make
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/classification.dir/depend.internal
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/classification.dir/CXX.includecache
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/classification.dir/DependInfo.cmake
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/classification.dir/cmake_clean.cmake
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/classification.dir/cpp_classification/
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/classification.dir/cpp_classification/classification.cpp.o
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/classification.dir/depend.make
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/classification.dir/link.txt
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/classification.dir/progress.make
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/convert_mnist_siamese_data.dir/
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/convert_mnist_siamese_data.dir/build.make
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/convert_mnist_siamese_data.dir/siamese/
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/convert_mnist_siamese_data.dir/siamese/convert_mnist_siamese_data.cpp.o
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/convert_mnist_siamese_data.dir/flags.make
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/convert_mnist_siamese_data.dir/depend.internal
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/convert_mnist_siamese_data.dir/CXX.includecache
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/convert_mnist_siamese_data.dir/DependInfo.cmake
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/convert_mnist_siamese_data.dir/cmake_clean.cmake
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/convert_mnist_siamese_data.dir/depend.make
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/convert_mnist_siamese_data.dir/link.txt
# openpose/build/caffe/src/openpose_lib-build/examples/CMakeFiles/convert_mnist_siamese_data.dir/progress.make
# openpose/build/caffe/src/openpose_lib-build/examples/mnist/
# openpose/build/caffe/src/openpose_lib-build/examples/mnist/convert_mnist_data
# openpose/build/caffe/src/openpose_lib-build/examples/mnist/convert_mnist_data.bin
# openpose/build/caffe/src/openpose_lib-build/examples/cpp_classification/
# openpose/build/caffe/src/openpose_lib-build/examples/cpp_classification/classification.bin
# openpose/build/caffe/src/openpose_lib-build/examples/cpp_classification/classification
# openpose/build/caffe/src/openpose_lib-build/docs/
# openpose/build/caffe/src/openpose_lib-build/docs/cmake_install.cmake
# openpose/build/caffe/src/openpose_lib-build/docs/Makefile
# openpose/build/caffe/src/openpose_lib-build/docs/CMakeFiles/
# openpose/build/caffe/src/openpose_lib-build/docs/CMakeFiles/progress.marks
# openpose/build/caffe/src/openpose_lib-build/docs/CMakeFiles/CMakeDirectoryInformation.cmake
# openpose/build/caffe/src/openpose_lib-build/cmake_install.cmake
# openpose/build/caffe/src/openpose_lib-build/CaffeTargets.cmake
# openpose/build/caffe/src/openpose_lib-build/Makefile
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/TargetDirectories.txt
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/lint.dir/
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/lint.dir/build.make
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/lint.dir/DependInfo.cmake
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/lint.dir/cmake_clean.cmake
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/lint.dir/progress.make
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/a.out
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/CMakeTmp/
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/CMakeRuleHashes.txt
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/CMakeOutput.log
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/3.13.0/
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/3.13.0/CMakeSystem.cmake
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/3.13.0/CMakeCXXCompiler.cmake
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/3.13.0/CMakeDetermineCompilerABI_C.bin
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/3.13.0/CMakeDetermineCompilerABI_CXX.bin
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/3.13.0/CompilerIdC/
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/3.13.0/CompilerIdC/a.out
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/3.13.0/CompilerIdC/CMakeCCompilerId.c
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/3.13.0/CompilerIdC/tmp/
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/3.13.0/CMakeCCompiler.cmake
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/3.13.0/CompilerIdCXX/
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/3.13.0/CompilerIdCXX/a.out
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/3.13.0/CompilerIdCXX/CMakeCXXCompilerId.cpp
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/3.13.0/CompilerIdCXX/tmp/
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/symlink_to_build.dir/
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/symlink_to_build.dir/build.make
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/symlink_to_build.dir/DependInfo.cmake
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/symlink_to_build.dir/cmake_clean.cmake
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/symlink_to_build.dir/progress.make
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/progress.marks
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/Makefile.cmake
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/cmake.check_cache
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/Makefile2
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/CMakeError.log
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/feature_tests.c
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/feature_tests.cxx
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/CMakeDirectoryInformation.cmake
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/Export/
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/Export/share/
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/Export/share/Caffe/
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/Export/share/Caffe/CaffeTargets.cmake
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/Export/share/Caffe/CaffeTargets-release.cmake
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/uninstall.dir/
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/uninstall.dir/build.make
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/uninstall.dir/DependInfo.cmake
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/uninstall.dir/cmake_clean.cmake
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/uninstall.dir/progress.make
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/hdf5/
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/hdf5/CMakeFiles/
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/hdf5/CMakeFiles/CMakeTmp/
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/hdf5/cmake_hdf5_test.cxx
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/hdf5/cmake_hdf5_test.c
# openpose/build/caffe/src/openpose_lib-build/CMakeFiles/feature_tests.bin
# openpose/build/caffe/src/openpose_lib-build/src/
# openpose/build/caffe/src/openpose_lib-build/src/gtest/
# openpose/build/caffe/src/openpose_lib-build/src/gtest/cmake_install.cmake
# openpose/build/caffe/src/openpose_lib-build/src/gtest/Makefile
# openpose/build/caffe/src/openpose_lib-build/src/gtest/CMakeFiles/
# openpose/build/caffe/src/openpose_lib-build/src/gtest/CMakeFiles/progress.marks
# openpose/build/caffe/src/openpose_lib-build/src/gtest/CMakeFiles/CMakeDirectoryInformation.cmake
# openpose/build/caffe/src/openpose_lib-build/src/gtest/CMakeFiles/gtest.dir/
# openpose/build/caffe/src/openpose_lib-build/src/gtest/CMakeFiles/gtest.dir/build.make
# openpose/build/caffe/src/openpose_lib-build/src/gtest/CMakeFiles/gtest.dir/flags.make
# openpose/build/caffe/src/openpose_lib-build/src/gtest/CMakeFiles/gtest.dir/cmake_clean_target.cmake
# openpose/build/caffe/src/openpose_lib-build/src/gtest/CMakeFiles/gtest.dir/DependInfo.cmake
# openpose/build/caffe/src/openpose_lib-build/src/gtest/CMakeFiles/gtest.dir/cmake_clean.cmake
# openpose/build/caffe/src/openpose_lib-build/src/gtest/CMakeFiles/gtest.dir/depend.make
# openpose/build/caffe/src/openpose_lib-build/src/gtest/CMakeFiles/gtest.dir/link.txt
# openpose/build/caffe/src/openpose_lib-build/src/gtest/CMakeFiles/gtest.dir/progress.make
# openpose/build/caffe/src/openpose_lib-build/src/caffe/
# openpose/build/caffe/src/openpose_lib-build/src/caffe/cmake_install.cmake
# openpose/build/caffe/src/openpose_lib-build/src/caffe/Makefile
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_cudnn_lrn_layer.cu.o
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_base_data_layer.cu.o
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_cudnn_lrn_layer.cu.o.depend
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_clip_layer.cu.o
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_log_layer.cu.o.cmake.pre-gen
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_batch_reindex_layer.cu.o
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_sigmoid_layer.cu.o.cmake.pre-gen
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_cudnn_tanh_layer.cu.o.depend
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_dropout_layer.cu.o.depend
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_eltwise_layer.cu.o.cmake.pre-gen
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_softmax_loss_layer.cu.o.Release.cmake
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_concat_layer.cu.o
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_cudnn_relu_layer.cu.o.depend
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_concat_layer.cu.o.depend
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_filter_layer.cu.o.Release.cmake
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_pooling_layer.cu.o.Release.cmake
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_concat_layer.cu.o.cmake.pre-gen
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_silence_layer.cu.o.Release.cmake
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_pooling_layer.cu.o
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_tanh_layer.cu.o.depend
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_elu_layer.cu.o.Release.cmake
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_elu_layer.cu.o.depend
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_cudnn_conv_layer.cu.o
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_batch_reindex_layer.cu.o.cmake.pre-gen
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_softmax_layer.cu.o.Release.cmake
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_cudnn_conv_layer.cu.o.depend
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_elu_layer.cu.o.cmake.pre-gen
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_pooling_layer.cu.o.depend
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_conv_layer.cu.o.depend
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_hdf5_output_layer.cu.o
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_swish_layer.cu.o
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_prelu_layer.cu.o
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_tile_layer.cu.o.depend
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_base_data_layer.cu.o.cmake.pre-gen
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_crop_layer.cu.o.depend
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_threshold_layer.cu.o.cmake.pre-gen
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_mvn_layer.cu.o.depend
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_inner_product_layer.cu.o.Release.cmake
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_reduction_layer.cu.o
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_softmax_layer.cu.o.depend
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_bnll_layer.cu.o.Release.cmake
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_im2col_layer.cu.o.cmake.pre-gen
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_cudnn_softmax_layer.cu.o.cmake.pre-gen
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_tanh_layer.cu.o
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_cudnn_pooling_layer.cu.o
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_accuracy_layer.cu.o.cmake.pre-gen
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_reduction_layer.cu.o.depend
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_cudnn_pooling_layer.cu.o.cmake.pre-gen
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_silence_layer.cu.o
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_bias_layer.cu.o.depend
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_log_layer.cu.o.depend
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_log_layer.cu.o
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_threshold_layer.cu.o.Release.cmake
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_sigmoid_cross_entropy_loss_layer.cu.o
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_mvn_layer.cu.o
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_absval_layer.cu.o.depend
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_clip_layer.cu.o.Release.cmake
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_sigmoid_layer.cu.o
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_reduction_layer.cu.o.Release.cmake
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_cudnn_lrn_layer.cu.o.Release.cmake
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_cudnn_relu_layer.cu.o.cmake.pre-gen
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_accuracy_layer.cu.o
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_contrastive_loss_layer.cu.o.Release.cmake
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_accuracy_layer.cu.o.depend
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_tile_layer.cu.o.cmake.pre-gen
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_euclidean_loss_layer.cu.o.Release.cmake
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_recurrent_layer.cu.o
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_recurrent_layer.cu.o.cmake.pre-gen
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_hdf5_data_layer.cu.o
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_cudnn_sigmoid_layer.cu.o.depend
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_lrn_layer.cu.o.cmake.pre-gen
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_silence_layer.cu.o.cmake.pre-gen
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_bias_layer.cu.o
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_crop_layer.cu.o.cmake.pre-gen
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_clip_layer.cu.o.cmake.pre-gen
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_base_data_layer.cu.o.depend
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_cudnn_deconv_layer.cu.o.depend
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_lstm_unit_layer.cu.o.depend
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_batch_norm_layer.cu.o.cmake.pre-gen
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_cudnn_conv_layer.cu.o.Release.cmake
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_lrn_layer.cu.o.Release.cmake
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_deconv_layer.cu.o
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_base_data_layer.cu.o.Release.cmake
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_split_layer.cu.o.depend
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_cudnn_conv_layer.cu.o.cmake.pre-gen
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_slice_layer.cu.o.cmake.pre-gen
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_cudnn_lcn_layer.cu.o
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_absval_layer.cu.o
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_recurrent_layer.cu.o.Release.cmake
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_bias_layer.cu.o.Release.cmake
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_batch_norm_layer.cu.o.Release.cmake
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_split_layer.cu.o.cmake.pre-gen
# openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_dropout_layer.cu.o.cmake.pre-gen
# ...
# openpose/3rdparty/caffe/src/caffe/test/test_protobuf.cpp
# openpose/3rdparty/caffe/src/caffe/test/test_accuracy_layer.cpp
# openpose/3rdparty/caffe/src/caffe/test/test_threshold_layer.cpp
# openpose/3rdparty/caffe/src/caffe/test/test_crop_layer.cpp
# openpose/3rdparty/caffe/src/caffe/test/test_hdf5data_layer.cpp
# openpose/3rdparty/caffe/src/caffe/test/test_concat_layer.cpp
# openpose/3rdparty/caffe/src/caffe/test/test_common.cpp
# openpose/3rdparty/caffe/src/caffe/test/test_util_blas.cpp
# openpose/3rdparty/caffe/src/caffe/test/test_solver.cpp
# openpose/3rdparty/caffe/src/caffe/test/test_inner_product_layer.cpp
# openpose/3rdparty/caffe/src/caffe/test/test_tile_layer.cpp
# openpose/3rdparty/caffe/src/caffe/test/test_convolution_layer.cpp
# openpose/3rdparty/caffe/src/caffe/test/test_im2col_layer.cpp
# openpose/3rdparty/caffe/src/caffe/test/test_hinge_loss_layer.cpp
# openpose/3rdparty/caffe/src/caffe/test/test_gradient_based_solver.cpp
# openpose/3rdparty/caffe/src/caffe/test/test_data_transformer.cpp
# openpose/3rdparty/caffe/src/caffe/test/test_hdf5_output_layer.cpp
# openpose/3rdparty/caffe/src/caffe/test/test_batch_norm_layer.cpp
# openpose/3rdparty/caffe/src/caffe/test/test_filler.cpp
# openpose/3rdparty/caffe/src/caffe/test/test_contrastive_loss_layer.cpp
# openpose/3rdparty/caffe/src/caffe/layer_factory.cpp
# openpose/3rdparty/caffe/src/caffe/solvers/
# openpose/3rdparty/caffe/src/caffe/solvers/sgd_solver.cu
# openpose/3rdparty/caffe/src/caffe/solvers/adagrad_solver.cu
# openpose/3rdparty/caffe/src/caffe/solvers/rmsprop_solver.cu
# openpose/3rdparty/caffe/src/caffe/solvers/adam_solver.cu
# openpose/3rdparty/caffe/src/caffe/solvers/adadelta_solver.cu
# openpose/3rdparty/caffe/src/caffe/solvers/rmsprop_solver.cpp
# openpose/3rdparty/caffe/src/caffe/solvers/adam_solver.cpp
# openpose/3rdparty/caffe/src/caffe/solvers/adadelta_solver.cpp
# openpose/3rdparty/caffe/src/caffe/solvers/adagrad_solver.cpp
# openpose/3rdparty/caffe/src/caffe/solvers/nesterov_solver.cpp
# openpose/3rdparty/caffe/src/caffe/solvers/sgd_solver.cpp
# openpose/3rdparty/caffe/src/caffe/solvers/nesterov_solver.cu
# openpose/3rdparty/caffe/src/caffe/proto/
# openpose/3rdparty/caffe/src/caffe/proto/caffe.proto
# openpose/3rdparty/caffe/.gitignore
# openpose/3rdparty/caffe/.travis.yml
# openpose/3rdparty/caffe/python/
# openpose/3rdparty/caffe/python/detect.py
# openpose/3rdparty/caffe/python/draw_net.py
# openpose/3rdparty/caffe/python/CMakeLists.txt
# openpose/3rdparty/caffe/python/caffe/
# openpose/3rdparty/caffe/python/caffe/classifier.py
# openpose/3rdparty/caffe/python/caffe/__init__.py
# openpose/3rdparty/caffe/python/caffe/detector.py
# openpose/3rdparty/caffe/python/caffe/draw.py
# openpose/3rdparty/caffe/python/caffe/_caffe.cpp
# openpose/3rdparty/caffe/python/caffe/pycaffe.py
# openpose/3rdparty/caffe/python/caffe/io.py
# openpose/3rdparty/caffe/python/caffe/net_spec.py
# openpose/3rdparty/caffe/python/caffe/test/
# openpose/3rdparty/caffe/python/caffe/test/test_io.py
# openpose/3rdparty/caffe/python/caffe/test/test_net.py
# openpose/3rdparty/caffe/python/caffe/test/test_python_layer_with_param_str.py
# openpose/3rdparty/caffe/python/caffe/test/test_draw.py
# openpose/3rdparty/caffe/python/caffe/test/test_net_spec.py
# openpose/3rdparty/caffe/python/caffe/test/test_solver.py
# openpose/3rdparty/caffe/python/caffe/test/test_layer_type_list.py
# openpose/3rdparty/caffe/python/caffe/test/test_nccl.py
# openpose/3rdparty/caffe/python/caffe/test/test_python_layer.py
# openpose/3rdparty/caffe/python/caffe/test/test_coord_map.py
# openpose/3rdparty/caffe/python/caffe/imagenet/
# openpose/3rdparty/caffe/python/caffe/imagenet/ilsvrc_2012_mean.npy
# openpose/3rdparty/caffe/python/caffe/coord_map.py
# openpose/3rdparty/caffe/python/classify.py
# openpose/3rdparty/caffe/python/requirements.txt
# openpose/3rdparty/caffe/python/train.py
# openpose/3rdparty/caffe/.git
# openpose/3rdparty/caffe/data/
# openpose/3rdparty/caffe/data/ilsvrc12/
# openpose/3rdparty/caffe/data/ilsvrc12/get_ilsvrc_aux.sh
# openpose/3rdparty/caffe/data/cifar10/
# openpose/3rdparty/caffe/data/cifar10/get_cifar10.sh
# openpose/3rdparty/caffe/data/mnist/
# openpose/3rdparty/caffe/data/mnist/get_mnist.sh
# openpose/3rdparty/caffe/.Doxyfile
# openpose/3rdparty/caffe/install_caffe_JetsonTX2_JetPack3.3.sh
# openpose/3rdparty/caffe/matlab/
# openpose/3rdparty/caffe/matlab/CMakeLists.txt
# openpose/3rdparty/caffe/matlab/hdf5creation/
# openpose/3rdparty/caffe/matlab/hdf5creation/.gitignore
# openpose/3rdparty/caffe/matlab/hdf5creation/store2hdf5.m
# openpose/3rdparty/caffe/matlab/hdf5creation/demo.m
# openpose/3rdparty/caffe/matlab/demo/
# openpose/3rdparty/caffe/matlab/demo/classification_demo.m
# openpose/3rdparty/caffe/matlab/+caffe/
# openpose/3rdparty/caffe/matlab/+caffe/get_solver.m
# openpose/3rdparty/caffe/matlab/+caffe/+test/
# openpose/3rdparty/caffe/matlab/+caffe/+test/test_solver.m
# openpose/3rdparty/caffe/matlab/+caffe/+test/test_io.m
# openpose/3rdparty/caffe/matlab/+caffe/+test/test_net.m
# openpose/3rdparty/caffe/matlab/+caffe/Net.m
# openpose/3rdparty/caffe/matlab/+caffe/private/
# openpose/3rdparty/caffe/matlab/+caffe/private/CHECK_FILE_EXIST.m
# openpose/3rdparty/caffe/matlab/+caffe/private/is_valid_handle.m
# openpose/3rdparty/caffe/matlab/+caffe/private/caffe_.cpp
# openpose/3rdparty/caffe/matlab/+caffe/private/CHECK.m
# openpose/3rdparty/caffe/matlab/+caffe/Blob.m
# openpose/3rdparty/caffe/matlab/+caffe/Solver.m
# openpose/3rdparty/caffe/matlab/+caffe/io.m
# openpose/3rdparty/caffe/matlab/+caffe/version.m
# openpose/3rdparty/caffe/matlab/+caffe/reset_all.m
# openpose/3rdparty/caffe/matlab/+caffe/imagenet/
# openpose/3rdparty/caffe/matlab/+caffe/imagenet/ilsvrc_2012_mean.mat
# openpose/3rdparty/caffe/matlab/+caffe/set_device.m
# openpose/3rdparty/caffe/matlab/+caffe/run_tests.m
# openpose/3rdparty/caffe/matlab/+caffe/get_net.m
# openpose/3rdparty/caffe/matlab/+caffe/set_mode_gpu.m
# openpose/3rdparty/caffe/matlab/+caffe/set_mode_cpu.m
# openpose/3rdparty/caffe/matlab/+caffe/Layer.m
# openpose/3rdparty/caffe/docker/
# openpose/3rdparty/caffe/docker/gpu/
# openpose/3rdparty/caffe/docker/gpu/Dockerfile
# openpose/3rdparty/caffe/docker/cpu/
# openpose/3rdparty/caffe/docker/cpu/Dockerfile
# openpose/3rdparty/caffe/docker/README.md
# openpose/3rdparty/caffe/cmake/
# openpose/3rdparty/caffe/cmake/Templates/
# openpose/3rdparty/caffe/cmake/Templates/CaffeConfigVersion.cmake.in
# openpose/3rdparty/caffe/cmake/Templates/CaffeConfig.cmake.in
# openpose/3rdparty/caffe/cmake/Templates/caffe_config.h.in
# openpose/3rdparty/caffe/cmake/Targets.cmake
# openpose/3rdparty/caffe/cmake/lint.cmake
# openpose/3rdparty/caffe/cmake/External/
# openpose/3rdparty/caffe/cmake/External/gflags.cmake
# openpose/3rdparty/caffe/cmake/External/glog.cmake
# openpose/3rdparty/caffe/cmake/Summary.cmake
# openpose/3rdparty/caffe/cmake/ProtoBuf.cmake
# openpose/3rdparty/caffe/cmake/Utils.cmake
# openpose/3rdparty/caffe/cmake/Dependencies.cmake
# openpose/3rdparty/caffe/cmake/Modules/
# openpose/3rdparty/caffe/cmake/Modules/FindAtlas.cmake
# openpose/3rdparty/caffe/cmake/Modules/FindMKL.cmake
# openpose/3rdparty/caffe/cmake/Modules/FindSnappy.cmake
# openpose/3rdparty/caffe/cmake/Modules/FindLMDB.cmake
# openpose/3rdparty/caffe/cmake/Modules/FindLevelDB.cmake
# openpose/3rdparty/caffe/cmake/Modules/FindGlog.cmake
# openpose/3rdparty/caffe/cmake/Modules/FindNCCL.cmake
# openpose/3rdparty/caffe/cmake/Modules/FindGFlags.cmake
# openpose/3rdparty/caffe/cmake/Modules/FindvecLib.cmake
# openpose/3rdparty/caffe/cmake/Modules/FindLAPACK.cmake
# openpose/3rdparty/caffe/cmake/Modules/FindOpenBLAS.cmake
# openpose/3rdparty/caffe/cmake/Modules/FindMatlabMex.cmake
# openpose/3rdparty/caffe/cmake/Modules/FindNumPy.cmake
# openpose/3rdparty/caffe/cmake/Cuda.cmake
# openpose/3rdparty/caffe/cmake/Uninstall.cmake.in
# openpose/3rdparty/caffe/cmake/Misc.cmake
# openpose/3rdparty/caffe/cmake/ConfigGen.cmake
# openpose/3rdparty/caffe/install_caffe_if_cuda8.sh
# openpose/3rdparty/windows/
# openpose/3rdparty/windows/getCaffe3rdparty.bat
# openpose/3rdparty/windows/getCaffe.bat
# openpose/3rdparty/windows/getSpinnaker.bat
# openpose/3rdparty/windows/getFreeglut.bat
# openpose/3rdparty/windows/getOpenCV.bat
# openpose/3rdparty/windows/wget/
# openpose/3rdparty/windows/wget/Version_wget-1.20.3-win64.txt
# openpose/3rdparty/windows/wget/wget.html
# openpose/3rdparty/windows/wget/wget.exe.debug
# openpose/3rdparty/windows/wget/COPYING
# openpose/3rdparty/windows/wget/wget.exe
# openpose/3rdparty/windows/unzip/
# openpose/3rdparty/windows/unzip/LICENSE.txt
# openpose/3rdparty/windows/unzip/unzip.exe
# openpose/3rdparty/pybind11/
# openpose/3rdparty/Versions.txt
# openpose/cmake/
# openpose/cmake/OpenPose_CPU.vcxproj.user
# openpose/cmake/Utils.cmake
# openpose/cmake/cmake_uninstall.cmake.in
# openpose/cmake/OpenPose_CL.vcxproj.user
# openpose/cmake/Modules/
# openpose/cmake/Modules/FindLIBIGL.cmake
# openpose/cmake/Modules/FindSpinnaker.cmake
# openpose/cmake/Modules/FindGlog.cmake
# openpose/cmake/Modules/FindGFlags.cmake
# openpose/cmake/Modules/FindCuDNN.cmake
# openpose/cmake/Modules/FindCaffe.cmake
# openpose/cmake/OpenPose.vcxproj.user
# openpose/cmake/Cuda.cmake
# openpose/cmake/OpenPoseConfig.cmake.in
# openpose/appveyor.yml
# -- GCC detected, adding compile flags
# -- GCC detected, adding compile flags
# -- Building with CUDA.
# -- CUDA detected: 10.1
# -- Found cuDNN: ver. 7.6.5 found (include: /usr/include, library: /usr/lib/x86_64-linux-gnu/libcudnn.so)
# -- Added CUDA NVCC flags for: sm_75
# -- Found cuDNN: ver. 7.6.5 found (include: /usr/include, library: /usr/lib/x86_64-linux-gnu/libcudnn.so)
# -- Found gflags  (include: /usr/include, library: /usr/lib/x86_64-linux-gnu/libgflags.so)
# -- Found glog    (include: /usr/include, library: /usr/lib/x86_64-linux-gnu/libglog.so)
# -- Caffe will be downloaded from source now. NOTE: This process might take several minutes depending
#         on your internet connection.
# -- Caffe has already been downloaded.
# HEAD is now at 1807aada Added Ampere arch's (CUDA11)
# -- Caffe will be built from source now.
# -- Adding Example calibration.bin
# -- Adding Example tutorial_add_module_custom_post_processing.bin
# -- Adding Example tutorial_api_thread_1_user_processing_function.bin
# -- Adding Example tutorial_api_thread_2_user_input_processing_output_and_datum.bin
# -- Adding Example openpose.bin
# -- Adding Example 01_body_from_image_default.bin
# -- Adding Example 02_whole_body_from_image_default.bin
# -- Adding Example 03_keypoints_from_image.bin
# -- Adding Example 04_keypoints_from_images.bin
# -- Adding Example 05_keypoints_from_images_multi_gpu.bin
# -- Adding Example 06_face_from_image.bin
# -- Adding Example 07_hand_from_image.bin
# -- Adding Example 08_heatmaps_from_image.bin
# -- Adding Example 09_keypoints_from_heatmaps.bin
# -- Adding Example 10_asynchronous_custom_input.bin
# -- Adding Example 11_asynchronous_custom_input_multi_camera.bin
# -- Adding Example 12_asynchronous_custom_output.bin
# -- Adding Example 13_asynchronous_custom_input_output_and_datum.bin
# -- Adding Example 14_synchronous_custom_input.bin
# -- Adding Example 15_synchronous_custom_preprocessing.bin
# -- Adding Example 16_synchronous_custom_postprocessing.bin
# -- Adding Example 17_synchronous_custom_output.bin
# -- Adding Example 18_synchronous_custom_all_and_datum.bin
# -- Adding Example handFromJsonTest.bin
# -- Adding Example resizeTest.bin
# -- Download the models.
# -- Downloading BODY_25 model...
# -- Model already exists.
# -- Not downloading body (COCO) model
# -- Not downloading body (MPI) model
# -- Downloading face model...
# -- Model already exists.
# -- Downloading hand model...
# -- Model already exists.
# -- Models Downloaded.
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /content/openpose/build
# [  2%] Built target openpose_lib
# [  2%] Building NVCC (Device) object src/openpose/CMakeFiles/openpose.dir/net/openpose_generated_maximumBase.cu.o
# [  2%] Building NVCC (Device) object src/openpose/CMakeFiles/openpose.dir/net/openpose_generated_nmsBase.cu.o
# [  3%] Linking CXX shared library libopenpose.so
# [ 41%] Built target openpose
# [ 43%] Linking CXX executable calibration.bin
# [ 47%] Built target openpose_core
# [ 47%] Linking CXX executable tutorial_api_thread_1_user_processing_function.bin
# [ 48%] Built target tutorial_api_thread_1_user_processing_function.bin
# [ 49%] Built target calibration.bin
# [ 50%] Linking CXX executable tutorial_add_module_custom_post_processing.bin
# [ 50%] Linking CXX executable tutorial_api_thread_2_user_input_processing_output_and_datum.bin
# [ 50%] Built target tutorial_api_thread_2_user_input_processing_output_and_datum.bin
# [ 50%] Linking CXX executable openpose.bin
# [ 50%] Built target tutorial_add_module_custom_post_processing.bin
# [ 50%] Linking CXX executable 18_synchronous_custom_all_and_datum.bin
# [ 50%] Built target openpose.bin
# [ 50%] Linking CXX executable 17_synchronous_custom_output.bin
# [ 50%] Built target 18_synchronous_custom_all_and_datum.bin
# [ 51%] Linking CXX executable 05_keypoints_from_images_multi_gpu.bin
# [ 52%] Built target 17_synchronous_custom_output.bin
# [ 52%] Linking CXX executable 03_keypoints_from_image.bin
# [ 52%] Built target 05_keypoints_from_images_multi_gpu.bin
# [ 52%] Linking CXX executable 06_face_from_image.bin
# [ 52%] Built target 03_keypoints_from_image.bin
# [ 53%] Linking CXX executable 07_hand_from_image.bin
# [ 53%] Built target 06_face_from_image.bin
# [ 53%] Linking CXX executable 04_keypoints_from_images.bin
# [ 53%] Built target 07_hand_from_image.bin
# [ 53%] Linking CXX executable 01_body_from_image_default.bin
# [ 54%] Built target 04_keypoints_from_images.bin
# [ 54%] Linking CXX executable 09_keypoints_from_heatmaps.bin
# [ 54%] Built target 01_body_from_image_default.bin
# [ 55%] Linking CXX executable 02_whole_body_from_image_default.bin
# [ 56%] Built target 09_keypoints_from_heatmaps.bin
# [ 56%] Linking CXX executable 13_asynchronous_custom_input_output_and_datum.bin
# [ 56%] Built target 02_whole_body_from_image_default.bin
# [ 56%] Linking CXX executable 08_heatmaps_from_image.bin
# [ 56%] Built target 13_asynchronous_custom_input_output_and_datum.bin
# [ 56%] Linking CXX executable 16_synchronous_custom_postprocessing.bin
# [ 56%] Built target 08_heatmaps_from_image.bin
# [ 56%] Linking CXX executable 11_asynchronous_custom_input_multi_camera.bin
# [ 56%] Built target 16_synchronous_custom_postprocessing.bin
# [ 56%] Linking CXX executable 14_synchronous_custom_input.bin
# [ 56%] Built target 11_asynchronous_custom_input_multi_camera.bin
# [ 57%] Linking CXX executable 15_synchronous_custom_preprocessing.bin
# [ 58%] Built target 14_synchronous_custom_input.bin
# [ 59%] Linking CXX executable 10_asynchronous_custom_input.bin
# [ 59%] Built target 15_synchronous_custom_preprocessing.bin
# [ 60%] Linking CXX executable 12_asynchronous_custom_output.bin
# [ 60%] Built target 10_asynchronous_custom_input.bin
# [ 61%] Linking CXX executable resizeTest.bin
# [ 61%] Built target 12_asynchronous_custom_output.bin
# [ 62%] Linking CXX executable handFromJsonTest.bin
# [ 62%] Built target resizeTest.bin
# [ 64%] Built target openpose_3d
# [ 65%] Built target openpose_calibration
# [ 65%] Linking CXX shared library libopenpose_face.so
# [ 68%] Built target openpose_face
# [ 72%] Built target openpose_filestream
# [ 72%] Linking CXX shared library libopenpose_gpu.so
# [ 73%] Built target openpose_gpu
# [ 73%] Linking CXX shared library libopenpose_pose.so
# [ 76%] Built target openpose_pose
# [ 77%] Linking CXX shared library libopenpose_hand.so
# [ 80%] Built target openpose_hand
# [ 81%] Building NVCC (Device) object src/openpose/net/CMakeFiles/openpose_net.dir/openpose_net_generated_maximumBase.cu.o
# [ 81%] Built target handFromJsonTest.bin
# [ 81%] Built target openpose_thread
# [ 83%] Built target openpose_tracking
# [ 83%] Linking CXX shared library libopenpose_unity.so
# [ 83%] Built target openpose_unity
# [ 83%] Linking CXX shared library libopenpose_gui.so
# [ 85%] Built target openpose_gui
# [ 89%] Built target openpose_producer
# [ 92%] Built target openpose_utilities
# [ 92%] Building NVCC (Device) object src/openpose/net/CMakeFiles/openpose_net.dir/openpose_net_generated_nmsBase.cu.o
# [ 92%] Linking CXX shared library libopenpose_wrapper.so
# [ 95%] Built target openpose_wrapper
# [ 96%] Linking CXX shared library libopenpose_net.so
# [100%] Built target openpose_net

# %% [markdown]
# ## Detect poses in a test video
#
# We are going to detect poses on a sample video from a clinic. In this case, the video is stored at https://github.com/stanfordnmbl/mobile-gaitlab/raw/master/demo/in/input.mp4.
#
# Click the Files folder icon ![fileFolderIcon.jpg](data:image/jpeg;base64,...) in the left-hand column to see the current files in your virtual Colab environment. After you run the code below, refresh the folder by clicking on the folder icon with the circular arrow ![refreshFolderIcon.jpg](data:image/jpeg;base64,...). You should see a new file called "input.mp4" in your list of files.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Let's view the video to see what we will be analyzing.

# %%
# Define function to display the video
def show_local_mp4_video(file_name, width=640, height=480):
  import io
  import base64
  from IPython.display import HTML
  video_encoded = base64.b64encode(io.open(file_name, 'rb').read())
  return HTML(data='''<video width="{0}" height="{1}" alt="test" controls>
                        <source src="data:video/mp4;base64,{2}" type="video/mp4" />
                      </video>'''.format(width, height, video_encoded.decode('ascii')))

# Display the video
show_local_mp4_video('input.mp4', width=960, height=720)

# %% [markdown]
# We will now run OpenPose, specifying our input video file (`input.mp4`) and asking it to output the following:
#
# * The body keypoints in a JSON format in the directory `openpose/output` and
# * A video of the keypoints (`openpose.avi`)
#
# Several other input, output, and run options are available and are described in the [OpenPose documentation](https://cmu-perceptual-computing-lab.github.io/openpose/web/html/doc/).
#
# In the code below, we also convert the output video into an MP4 video (`output.mp4`) for viewing.
#
# NOTE: For these examples, the openpose command must be run from the openpose folder, so that it can locate the supporting files.

# %%
# delete files from previous runs of this script
# !rm openpose.avi

# detect poses in these video frames using OpenPose
# !cd openpose && /content/drive/MyDrive/LAEO_OP/test/Got01.mp4 --video ./Got01.mp4 --write_json /content/drive/MyDrive/LAEO_OP/keypoints/ --display 0  --write_video /content/drive/MyDrive/LAEO_OP/keypoints/

# convert the video output result into MP4 so we can visualize it using the 'show_local_mp4_video' function we defined above
# !ffmpeg -y -loglevel info -i openpose.avi output.mp4
# Out:
# /bin/bash: /content/drive/MyDrive/LAEO_OP/test/Got01.mp4: Permission denied

# %% [markdown]
# TROUBLESHOOTING: If you get an error message about `Cuda check failed`, this is likely because Google Colab cannot allocate a GPU for you to run OpenPose. Make sure you have set the notebook to use the GPU:
#
#
# 1.   Select Runtime->Change runtime type
# 2.   Choose `GPU` from the pull-down
# 1.   Click `SAVE`
#
# If the setting is correct, try running the notebook at another time.
#
#
# Finally, we can visualize the results:

# %%
show_local_mp4_video('output.mp4', width=960, height=720)

# %% [markdown]
# ## View and interpret OpenPose JSON output
#
# The output of OpenPose for each frame is saved in a JSON file.
#
# You can view the list of output files by clicking on the Files folder openpose -> output. There you will see a list of files named using the format `input_###_keypoints.json` where ### is a number.
#
# Let's print out one of these files to see its structure.

# %%
# Load JSON file
import json

with open('openpose/output/input_000000000100_keypoints.json') as json_file:
    data = json.load(json_file)

print(json.dumps(data, indent=4))

# %% [markdown]
# The information in the JSON file is stored in an array named `data`. For each frame, OpenPose tries to detect all the people in it. The coordinates of each person are stored in the `data["people"]` list. You access the keypoints in this way: `data["people"][i]["pose_keypoints_2d"]`, where `i` is the index of the person (with the first person having an index of 0). Each person is encoded as a 75-dimensional vector, 3 values for each of 25 different keypoints. Columns with indexes `3*k, 3*k+1` and `3*k+2` correspond to `X, Y` and `confidence` of the given keypoint, where `k` is the index of the keypoint (where the first keypoint has an index of 0). Please refer to the figure below for interpretation of the index `k`.
#
# Example: To access the `X` value of the second keypoint (k=1), you would use the following: `data["people"][0]["pose_keypoints_2d"][3]`

# %% [markdown]
# ![picture](https://user-images.githubusercontent.com/29478970/76984773-94e34580-693f-11ea-9bcd-7af6fbb1d521.png)

# %% [markdown]
# For clarity, we name all indices using short keywords, for example, an index of 2 refers to the right shoulder (RSHO):

# %%
NOSE = 0
NECK = 1
RSHO = 2
RELB = 3
RWRI = 4
LSHO = 5
LELB = 6
LWRI = 7
MHIP = 8
RHIP = 9
RKNE = 10
RANK = 11
LHIP = 12
LKNE = 13
LANK = 14
REYE = 15
LEYE = 16
REAR = 17
LEAR = 18
LBTO = 19
LSTO = 20
LHEL = 21
RBTO = 22
RSTO = 23
RHEL = 24

print("DONE: Short keywords assigned")

# %% [markdown]
# ## Convert JSON files to a time series of keypoints
#
# To run our analysis, we want to load data from all the JSON files into memory. In this case, we name that data array `res`. We will loop through all the files and use the functions from the numpy (np) package to store the subject's data as an array with 344 rows (one for each file/frame) and 75 columns. In our script, we determine the number of frames by counting the number of files in the directory.
#
# NOTE: We are using our knowledge/assumption that there is only one person visible in each frame.

# %%
import numpy as np
import pandas as pd

def convert_json2csv(json_directory):
    # determine the number of frames
    nframes = len(os.listdir(json_directory))
  
    # initialize res to be array of NaN
    res = np.zeros((nframes,75))
    res[:] = np.nan
    
    # read in JSON files
    for frame in range(0,nframes):
        test_image_json = '%sinput_%s_keypoints.json' %            (json_directory, str(frame).zfill(12))

        if not os.path.isfile(test_image_json):
            break
        with open(test_image_json) as data_file:  
            data = json.load(data_file)

        for person in data['people']:
            keypoints = person['pose_keypoints_2d']
            xcoords = [keypoints[i] for i in range(len(keypoints)) if i % 3 == 0]
            counter = 0
            res[frame,:] = keypoints
            break

    return res

res = convert_json2csv("openpose/output/")
pd.DataFrame(res) # only for clean display

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Diagnostic plots
#
# Now we plot some of the trajectories to see whether we need to clean them up using signal processing techniques.

# %%
import matplotlib.pyplot as plt

plt.plot(res[:,(NOSE*3)])
plt.plot(res[:,(NOSE*3+1)])
plt.xlabel("video frame")
plt.ylabel("nose position")
plt.legend(('x','y'))

# %% [markdown]
# Above we plotted the trajectory of the NOSE keypoint (index = 0). We see that around frame 150, there is some discontinuity. Also, some high frequency noise is present in the signals. Let's check if the same problems show up in curves that we are interested in for computing knee flexion, i.e., trajectories of the right ankle, knee, and hip.

# %%
# Features to plot for diagnostics
PLOT_COLS = {
    "Right ankle": RANK,
    "Right knee": RKNE,
    "Right hip": RHIP,
}

# The show_plots function displays a set of curves for each keypoint.
# We will use the show_plots again with different data arrays, 
# so we include the cols_per_point argument to provide flexibility 
# in specifying how many columns of the array are associated with a 
# given keypoint.
def show_plots(keypoint_array, cols_per_point=3):
    for name, col in PLOT_COLS.items():
        fig, ax = plt.subplots(figsize=(5, 5))
        ax.spines['right'].set_visible(False)
        ax.spines['top'].set_visible(False)
        plt.title(name,fontsize=24)
        plt.xlabel("video frame",fontsize=17)
        plt.ylabel("position",fontsize=17)

        plt.plot(keypoint_array[:,[col*cols_per_point,]], linestyle="-", linewidth=2.5)
        plt.plot(keypoint_array[:,[col*cols_per_point+1,]], linestyle="-", linewidth=2.5)
        plt.legend(['x', 'y'],loc=1)

show_plots(res)

# %% [markdown]
# We also see discontinuity and some high frequency noise in these signals, so we will clean them up using signal processing techniques.

# %% [markdown]
# ## Clean up signals
#
# **Discontinuities and Missing Data:** We will treat the discontinuities like missing data and use linear interpolation to fill in the missing data. There are several other ways to deal with missing data, and we encourage you to explore these for your research projects. You can find many resources online on this topic (search for "missing data in time series"), so we will not go over this here. We use linear interpolation because it is straightforward.
#
# For the interpolation process, we first want to simplify the data we use. We will copy the JSON output data into the `res_processed` variable, drop the confidence column which we don't need for interpolation, and replace values for undetected keypoints with NaN.

# %%
# The 3rd column associated with each keypoint in the OpenPose output 
# is the confidence score. We won't be using it in this notebook so 
# we can drop it

def drop_confidence_cols(keypoint_array):
    num_parts = keypoint_array.shape[1]/3 # should give 25 (# of OpenPose keypoints)
    processed_cols = [True,True,False] * int(num_parts) 
    return keypoint_array[:,processed_cols]

res_processed = res.copy()
res_processed = drop_confidence_cols(res_processed)

# if keypoint is not detected, OpenPose returns 0. For undetected keypoints,
# we change their values to NaN. Wo do it for all dimensions of all keypoints
# in all frames at once
res_processed[res_processed < 0.0001] = np.NaN 

# Note that we use res_processed < 0.0001 instead of res_processed == 0.0.
# While in the case of this video it makes no difference, it is usually
# a good practice in computer science to account for the fact that 
# 0.0 might be actually actually represented as a number slightly greater than
# 0. See more on this topic here
# https://randomascii.wordpress.com/2012/02/25/comparing-floating-point-numbers-2012-edition/

pd.DataFrame(res_processed)

# %% [markdown]
# You will see that this new data array only has 50 columns, compared with the original 75, reflecting the deletion of the columns with the confidence values. Also, notice that the first time point for keypoint 17 (columns 34 and 35 in row 0) now have NaN, replacing the zeros that were originally in columns 51 and 52 of that row.
#
# Next, we replace NaNs with linearly interpolated values and we plot the results to see that the discontinuities are no longer present.
#
# For those interested in understanding the details of the code, the key functions here are:
#
# * `interpolate.interp1d`, which performs the 1D interpolation and is provided through SciPy. The
# full documentation for this function is located [here](https://docs.scipy.org/doc/scipy/reference/generated/scipy.interpolate.interp1d.html).
# *  `np.nanmean`, which computes the mean for an array (ignoring NaN) and is provided through the NumPy package for scientific computing. The full documentation for this function is located [here](https://numpy.org/doc/stable/reference/generated/numpy.nanmean.html?highlight=nanmean#numpy.nanmean).

# %%
from scipy import interpolate

# interpolate to fill nan values
def fill_nan(A):
    inds = np.arange(A.shape[0]) 
    good = np.where(np.isfinite(A))
    if(len(good[0]) <= 1):
        return A
   
    # linearly interpolate and then fill the extremes with the mean (relatively similar to)
    # what kalman does 
    f = interpolate.interp1d(inds[good], A[good],kind="linear",bounds_error=False)
    B = np.where(np.isfinite(A),A,f(inds))
    B = np.where(np.isfinite(B),B,np.nanmean(B))
    return B
    
def impute_frames(frames):
    return np.apply_along_axis(fill_nan,arr=frames,axis=0)

res_processed = impute_frames(res_processed)
show_plots(res_processed, 2)

# %% [markdown]
# **Noisy Data:** We remove high frequency noise by smoothing the data with a Gaussian filter. Since the observed noise is of low magnitude and high frequency, it is relatively easy to filter out this noise with many popular methods. We chose the Gaussian filter in this tutorial for its simplicity of use.
#
# There are a number of other approaches for removing high frequency noise in a signal. Which is appropriate depends on the nature of your data. These [course notes](https://ggbaker.ca/data-science/content/filtering.html) from Greg Baker at Simon Fraser University provide a useful explanation of some of these other options.
#
# In this example, we use a Gaussian kernel with a standard deviation of 1. The documentation for the `gaussian_filter1d` function we use is [here](https://docs.scipy.org/doc/scipy/reference/generated/scipy.ndimage.gaussian_filter1d.html).

# %%
from scipy.ndimage.filters import gaussian_filter1d

# Remove high frequency noise
def filter_frames(frames, sd=1):
    return np.apply_along_axis(lambda x: gaussian_filter1d(x,sd),
                               arr = frames,
                               axis = 0)

res_processed = filter_frames(res_processed, 1)
show_plots(res_processed, 2)

# %% [markdown]
# If you compare these curves with the ones produced in the previous cell, you will notice that these curves are much smoother.
#
# **Bias:** Bias refers to a systemic error. In our case, the manner in which the video was recorded resulted in subjects systemically appearing smaller, then larger, and then smaller again due to the changing camera angle and distance from the subject. This resulted in varying lengths for the body parts that did not accurately reflect reality.
#
# To compensate for this bias, we therefore normalize each frame by (approximately) the length of the subject's femur. The premise is to choose a segment of a fixed length and divide all dimensions by this length. As a result, each pose has exactly the same normalized femur length, and the other segments have a length defined relative to the femur length. The length for each segment should be fairly constant from frame to frame, since they have a relatively fixed proportion to the femur in each frame. We chose the femur as it's relatively long, and therefore its measurement is more robust to noise.

# %%
# Find mean and standard deviation for debiasing
def find_mid_sd(signal_array):
    num_parts = signal_array.shape[1]/2 

    # Derive mid hip position
    mhip_x = ((signal_array[:,2*RHIP] + signal_array[:,2*LHIP])/2).reshape(-1,1)
    mhip_y = ((signal_array[:,2*RHIP+1] + signal_array[:,2*LHIP+1])/2).reshape(-1,1)
    mhip_coords = np.hstack([mhip_x,mhip_y]*int(num_parts))

    # Normalize to hip-knee distance
    topoint = lambda x: range(2*x,2*x+2)
    scale_vector_R = np.apply_along_axis(lambda x: np.linalg.norm(x[topoint(RHIP)] -
                                                                  x[topoint(RKNE)]),1,signal_array)
    scale_vector_L = np.apply_along_axis(lambda x: np.linalg.norm(x[topoint(LHIP)] -
                                                                  x[topoint(LKNE)]),1,signal_array)
    scale_vector = ((scale_vector_R + scale_vector_L)/2.0).reshape(-1,1)
    return mhip_coords, scale_vector

res_mhip_coords, res_scale_vector = find_mid_sd(res_processed)
res_processed = (res_processed-res_mhip_coords)/res_scale_vector
show_plots(res_processed, 2)

# %% [markdown]
# Note how the y coordinate (orange) in the normalized curve varies around a fairly constant position, compared to the plots in the previous cell without normalization! In the previous cell, the y position (orange) displayed an underlying "u" shape.

# %% [markdown]
# # Analysis

# %% [markdown]
# ## Derive joint angles
#
# As we are interested in the knee flexion angle, we will look at the angle formed by the keypoints at the ankle, knee, and hip. We do this by taking the arccosine of the normalized dot product between the ankle-knee vector and the knee-hip vector.

# %%
def get_angle(A,B,C,centered_filtered):
   
    # finds the angle ABC, assumes that confidence columns have been removed
    # A,B and C are integers corresponding to different keypoints
    
    p_A = np.array([centered_filtered[:,2*A],centered_filtered[:,2*A+1]]).T
    p_B = np.array([centered_filtered[:,2*B],centered_filtered[:,2*B+1]]).T
    p_C = np.array([centered_filtered[:,2*C],centered_filtered[:,2*C+1]]).T
    p_BA = p_A - p_B
    p_BC = p_C - p_B
    dot_products = np.sum(p_BA*p_BC,axis=1)
    norm_products = np.linalg.norm(p_BA,axis=1)*np.linalg.norm(p_BC,axis=1)
    return np.arccos(dot_products/norm_products)

# get the knee angle and convert from radians to degrees
knee_angle = (np.pi - get_angle(RANK, RKNE, RHIP, res_processed))*180/np.pi

# plot the knee angle
plt.plot(knee_angle)
plt.xlabel("video frame")
plt.ylabel("knee angle (degrees)")

# %% [markdown]
# ## Divide time series into gait cycles
#
# As we are interested in the knee flexion over a gait cycle, we will divide the time series into segments. For simplicity, we will define a gait cycle as a *segment between timepoints when a) the distance between the toes on the right and left legs are at a maximum **and** b) the right toes are on the right and the left toes are on the left in the sagittal plane view*.
#
# First, we will compute the distance between the toes on the right and left legs and store that in the variable `dst_org`. We then plot that distance.

# %%
def get_distance(A,B,centered_filtered):
    p_A = np.array([centered_filtered[:,2*A],centered_filtered[:,2*A+1]]).T
    p_B = np.array([centered_filtered[:,2*B],centered_filtered[:,2*B+1]]).T    
    p_BA = p_A - p_B
    return np.linalg.norm(p_BA,axis=1)

dst_org = get_distance(RBTO, LBTO, res_processed) * np.sign(res_processed[:,LBTO*2] - res_processed[:,RBTO*2])
plt.plot(dst_org)
plt.xlabel("video frame")
plt.ylabel("distance between right and left toes")

# %% [markdown]
# In the plot above, there is some noise around on either side of frame 100, so we'll smooth the signal using a Gaussian filter as we did previously. The smoothed distance data is stored in the variable `dst`.

# %%
dst = gaussian_filter1d(dst_org.copy(),5)
plt.plot(dst)
plt.xlabel("video frame")
plt.ylabel("distance between right and left toes, smoothed")

# %% [markdown]
# Now we need to detect the maximum distance between the toes. We will do that by finding the peaks, which are clearly visible. We will use a simple algorithm for peak detection and store the indices for the peaks, along with the peak values, in a two-column variable called `maxs`.

# %%
# Peak detection script converted from MATLAB script
# at http://billauer.co.il/peakdet.html
#    
# Returns two arrays
#    
# function [maxtab, mintab]=peakdet(v, delta, x)
# PEAKDET Detect peaks in a vector
# [MAXTAB, MINTAB] = PEAKDET(V, DELTA) finds the local
# maxima and minima ("peaks") in the vector V.
# MAXTAB and MINTAB consists of two columns. Column 1
# contains indices in V, and column 2 the found values.
#     
# With [MAXTAB, MINTAB] = PEAKDET(V, DELTA, X) the indices
# in MAXTAB and MINTAB are replaced with the corresponding
# X-values.
#
# A point is considered a maximum peak if it has the maximal
# value, and was preceded (to the left) by a value lower by
# DELTA.
#
# Eli Billauer, 3.4.05 (Explicitly not copyrighted).
# This function is released to the public domain; Any use is allowed.
def peakdet(v, delta, x = None):
    maxtab = []
    mintab = []
       
    if x is None:
        x = np.arange(len(v))
    
    v = np.asarray(v)
    
    if len(v) != len(x):
        sys.exit('Input vectors v and x must have same length')
    
    if not np.isscalar(delta):
        sys.exit('Input argument delta must be a scalar')
    
    if delta <= 0:
        sys.exit('Input argument delta must be positive')
    
    mn, mx = np.Inf, -np.Inf
    mnpos, mxpos = np.NaN, np.NaN
    
    lookformax = True
    
    for i in np.arange(len(v)):
        this = v[i]
        if this > mx:
            mx = this
            mxpos = x[i]
        if this < mn:
            mn = this
            mnpos = x[i]
        
        if lookformax:
            if this < mx-delta:
                maxtab.append((mxpos, mx))
                mn = this
                mnpos = x[i]
                lookformax = False
        else:
            if this > mn+delta:
                mintab.append((mnpos, mn))
                mx = this
                mxpos = x[i]
                lookformax = True

    return np.array(maxtab), np.array(mintab)

maxs, mins = peakdet(dst, 0.5)

print("DONE: maximums and minimums identified")

# %% [markdown]
# We now add vertical lines to the identified peak locations in the plot below. This will allow us to do a visual check to see if the peaks are identified correctly.

# %%
# plot the smoothed distance curve
plt.plot(dst)
plt.xlabel("video frame")
plt.ylabel("distance between right and left toes, smoothed")

# plot a vertical line at each point identified to have a maximum
for mm in maxs.tolist():
     plt.axvline(x=mm[0], color="orange")

# %% [markdown]
# The peaks appear to be identified correctly, so we will use
# these video frames to similarly mark the split between gait cycles on the knee angle time series.

# %%
# plot the knee angle curve
plt.plot(knee_angle)
plt.xlabel("video frame")
plt.ylabel("knee angle (degrees)")

# plot a vertical line at each split between gait cycles
for mm in maxs.tolist():
     plt.axvline(x=mm[0], color="orange")

# %% [markdown]
# We will extract the knee angles for the first 4 full segments, or gait cycles in this case, and store them in the variable `segments` to be used for further analysis and visualization.

# %%
segments = []
sstart = int(maxs[0][0])
for i in range(1,5):
    end = int(maxs[i][0])
    segments.append(knee_angle[sstart:end])
    print("Segment from {} to {}".format(sstart,end))
    sstart = end

# %% [markdown]
# # Report results

# %% [markdown]
# ## Plot knee angle for four gait cycles and export the plot
#
# We can now visually compare the knee angle over the first four gait cycles. After you run the cell below, you should see a plot with four curves, one for each gait cycle. Using the `plt.savefig` command, we also exported this plot to a file called "curves.png" that should appear in your Files folder to the left.

# %%
fig, ax = plt.subplots(figsize=(7, 5))
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.title("Approx. planar knee angle",fontsize=24)
plt.xlabel("gait cycle (in %)",fontsize=17)
plt.ylabel("angle (in degrees)",fontsize=17)

# Because each gait cycle has a slightly different number of points, 
# we must interpolate the data for each gait cycle so that
# each gait cycle has the same number of points in order to plot
# them together. Here we choose 100 points.
grid = np.linspace(0.0, 1.0, num=100)
curves = np.zeros([4,100])

for i in range(4):
    org_space = np.linspace(0.0, 1.0, num=int(segments[i].shape[0]))
    f = interpolate.interp1d(org_space, segments[i], kind="linear")
    plt.plot(grid*100, f(grid), linestyle="-", linewidth=2.5)
    plt.legend(["Cycle {}".format(k) for k in range(1,5)],loc=1)
    curves[i,:] = f(grid)

plt.savefig("curves.png")

# %% [markdown]
# ## Export cleaned up trajectories

# %% [markdown]
# We can also save any of our data to a text file. Below we save the trajectories from the first four gait cycles to a file called "trajectories.csv." After running the cell below, you should see that file in your Files folder to the left.

# %%
np.savetxt("trajectories.csv", curves, delimiter=",")

# %% [markdown]
# # Experiment with the Code
#
# Congratulations! You've completed your first video analysis with OpenPose. Here are a few activities you can try to increase your familiarity with the code. They are ordered from simplest to most complex.
#
# * Change the variance of the Gaussian smoothing filter to 5. How does this change the calculated joint angles?
# * Plot 4 gait cycles of the ankle flexion angle
# * Compute the mean and variance of peak knee flexion across 4 gait cycles
# * Run the scripts on another video https://github.com/stanfordnmbl/mobile-gaitlab/blob/master/demo/in/input1.mp4?raw=true. Note that because of people in the background, this video needs more preprocessing. Some of the assumptions we made in the code above will no longer be true.
# * Install keras and run neural networks from our study (https://github.com/stanfordnmbl/mobile-gaitlab/) to get better predictors of gait parameters from videos.

# %% [markdown]
# # Other resources
#
# * Our publication on our study on gait analysis in Cerebral Palsy population: https://www.nature.com/articles/s41467-020-17807-z
# * Code from our study and demo of neural networks: https://github.com/stanfordnmbl/mobile-gaitlab
# * OpenPose repository: https://github.com/CMU-Perceptual-Computing-Lab/openpose
# * Facebook's software for estimating 3d poses in videos: https://github.com/facebookresearch/VideoPose3D
# * DeepLabCut, software for creating virtual markers for different body parts in different species (not just humans) from videos: http://www.mousemotorlab.org/deeplabcut

# %% [markdown]
# #Feedback
#
# This notebook is a work-in-progress and we welcome your feedback on how to increase its usefulness. Email comments to us at [mobilize-center@stanford.edu](mailto:mobilize-center@stanford.edu) or submit an issue on GitHub.

# %% [markdown]
# ---

# %% [markdown]
# Version 1.04
#
# Creator: Lukasz Kidzinski | Contributors: Lukasz Kidzinski, Joy Ku
# Last Updated on Mar. 10, 2021
#
# This notebook is made available under the [Apache 2.0 license](https://www.apache.org/licenses/LICENSE-2.0).
#
# Note that software used within the notebook might have different licenses. Please refer to the documentation for individual software and packages. In particular, OpenPose is free only for non-commercial use (see its [license](https://github.com/CMU-Perceptual-Computing-Lab/openpose/blob/master/LICENSE) for details). For an open-source alternative , see [Detectron2](https://github.com/facebookresearch/detectron2) for a keypoint detection algorithm under Apache 2.0 license.
